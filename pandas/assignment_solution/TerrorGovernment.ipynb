# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("././terrorismData.csv")

# %%
df = df[df.Country == "India"]
df.reset_index(inplace=True,drop=True)
df
# Out:
#        Year  Month  Day Country              State      Region           City  \
# 0      1972      2   22   India              Delhi  South Asia      New Delhi
# 1      1975      1    2   India              Bihar  South Asia     Samastipur
# 2      1976      5   26   India              Delhi  South Asia      New Delhi
# 3      1977      9   28   India        Maharashtra  South Asia         Bombay
# 4      1979      1   13   India              Assam  South Asia        Unknown
# ...     ...    ...  ...     ...                ...         ...            ...
# 11955  2017     12   30   India             Kerala  South Asia  Koothuparamba
# 11956  2017     12   30   India       Chhattisgarh  South Asia       Toylanka
# 11957  2017     12   31   India  Jammu and Kashmir  South Asia      Lethapora
# 11958  2017     12   31   India              Assam  South Asia        Hungrum
# 11959  2017     12   31   India            Manipur  South Asia         Imphal
#
# ...

# %%
df.index[df.Year == 2014]
# Out:
# Int64Index([8225, 8226, 8227, 8228, 8229, 8230, 8231, 8232, 8233, 8234,
#             ...
#             9075, 9076, 9077, 9078, 9079, 9080, 9081, 9082, 9083, 9084],
#            dtype='int64', length=860)

# %%
df1 = df.iloc[8225:,:]
df1.reset_index(inplace=True,drop=True)
df1
# Out:
#       Year  Month  Day Country              State      Region           City  \
# 0     2014      1    1   India            Manipur  South Asia      Singjamei
# 1     2014      1    1   India            Manipur  South Asia         Imphal
# 2     2014      1    1   India            Haryana  South Asia        Dikadla
# 3     2014      1    1   India             Odisha  South Asia         Supalu
# 4     2014      1    1   India       Chhattisgarh  South Asia          Matda
# ...    ...    ...  ...     ...                ...         ...            ...
# 3730  2017     12   30   India             Kerala  South Asia  Koothuparamba
# 3731  2017     12   30   India       Chhattisgarh  South Asia       Toylanka
# 3732  2017     12   31   India  Jammu and Kashmir  South Asia      Lethapora
# 3733  2017     12   31   India              Assam  South Asia        Hungrum
# 3734  2017     12   31   India            Manipur  South Asia         Imphal
#
# ...

# %%
df1.index[df1.Month == 5]
# Out:
# Int64Index([ 338,  339,  340,  341,  342,  343,  344,  345,  346,  347,
#             ...
#             3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192],
#            dtype='int64', length=368)

# %%
df1 = df1.iloc[338:,:]
df1.reset_index(inplace=True,drop=True)
df1
# Out:
#       Year  Month  Day Country              State      Region           City  \
# 0     2014      5    1   India         Tamil Nadu  South Asia        Chennai
# 1     2014      5    1   India         Tamil Nadu  South Asia        Chennai
# 2     2014      5    1   India              Assam  South Asia    Narsingbari
# 3     2014      5    1   India              Assam  South Asia          Baska
# 4     2014      5    1   India              Assam  South Asia      Kokrajhar
# ...    ...    ...  ...     ...                ...         ...            ...
# 3392  2017     12   30   India             Kerala  South Asia  Koothuparamba
# 3393  2017     12   30   India       Chhattisgarh  South Asia       Toylanka
# 3394  2017     12   31   India  Jammu and Kashmir  South Asia      Lethapora
# 3395  2017     12   31   India              Assam  South Asia        Hungrum
# 3396  2017     12   31   India            Manipur  South Asia         Imphal
#
# ...

# %%
df1.index[df1.Day == 26]
# Out:
# Int64Index([  61,   62,   63,  134,  185,  186,  187,  188,  189,  190,
#             ...
#             3107, 3169, 3255, 3256, 3257, 3317, 3318, 3319, 3320, 3321],
#            dtype='int64', length=131)

# %%
df1 = df1.iloc[61:,:]
df1.reset_index(inplace=True,drop=True)
df1
# Out:
#       Year  Month  Day Country              State      Region           City  \
# 0     2014      5   26   India     Andhra Pradesh  South Asia    Bandlapalli
# 1     2014      5   26   India        West Bengal  South Asia   Sandeshkhali
# 2     2014      5   26   India        West Bengal  South Asia   Sandeshkhali
# 3     2014      5   27   India  Jammu and Kashmir  South Asia          Khour
# 4     2014      5   27   India             Odisha  South Asia      Bikrampur
# ...    ...    ...  ...     ...                ...         ...            ...
# 3331  2017     12   30   India             Kerala  South Asia  Koothuparamba
# 3332  2017     12   30   India       Chhattisgarh  South Asia       Toylanka
# 3333  2017     12   31   India  Jammu and Kashmir  South Asia      Lethapora
# 3334  2017     12   31   India              Assam  South Asia        Hungrum
# 3335  2017     12   31   India            Manipur  South Asia         Imphal
#
# ...

# %%
# hence, total attacks in india in this period = 3336
# lets calculate the most active terror group ignoring unknown groups

df2 = df1.drop(df1.index[df1.Group == "Unknown"])
df2.reset_index(inplace=True,drop=True)
df2
# Out:
#       Year  Month  Day Country              State      Region  \
# 0     2014      5   27   India          Meghalaya  South Asia
# 1     2014      5   28   India       Chhattisgarh  South Asia
# 2     2014      5   28   India             Odisha  South Asia
# 3     2014      5   28   India             Odisha  South Asia
# 4     2014      5   29   India        Maharashtra  South Asia
# ...    ...    ...  ...     ...                ...         ...
# 2052  2017     12   28   India              Bihar  South Asia
# 2053  2017     12   28   India            Manipur  South Asia
# 2054  2017     12   30   India       Chhattisgarh  South Asia
# 2055  2017     12   31   India  Jammu and Kashmir  South Asia
# 2056  2017     12   31   India              Assam  South Asia
#
#                      City   Latitude  Longitude  \
# 0          Daji Badimagre  25.396733  90.475623
# 1        Bijapur district  18.797297  80.813178
# 2                 Kambesu  19.280713  83.584336
# ...

# %%
df2.Group.mode()
# Out:
# 0    Maoists
# dtype: object

# %%
# i.e, most active terror group is Maoists
