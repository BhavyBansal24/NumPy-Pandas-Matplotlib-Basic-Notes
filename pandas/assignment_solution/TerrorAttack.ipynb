# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("././terrorismData.csv")
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
df.Country.mode()
# Out:
# 0    Iraq
# dtype: object

# %%
# Country with highest number of terror attack is Iraq
# lets calculate number of attacks in iraq

df2 = df[df.Country == "Iraq"]
df2.reset_index(inplace=True,drop=True)
df2
# Out:
#        Year  Month  Day Country    State                      Region  \
# 0      1975      3    1    Iraq  Nineveh  Middle East & North Africa
# 1      1976     12   15    Iraq  Baghdad  Middle East & North Africa
# 2      1976     12   18    Iraq  Unknown  Middle East & North Africa
# 3      1976     12   24    Iraq  Baghdad  Middle East & North Africa
# 4      1979      6   15    Iraq    Basra  Middle East & North Africa
# ...     ...    ...  ...     ...      ...                         ...
# 24631  2017     12   30    Iraq   Kirkuk  Middle East & North Africa
# 24632  2017     12   31    Iraq   Diyala  Middle East & North Africa
# 24633  2017     12   31    Iraq  Saladin  Middle East & North Africa
# 24634  2017     12   31    Iraq  Nineveh  Middle East & North Africa
# 24635  2017     12   31    Iraq   Diyala  Middle East & North Africa
#
#                City   Latitude  Longitude                   AttackType  \
# ...

# %%
# no of attacks in iraq is 24636
# now lets calculate year with most no of attacks

df2.Year.mode()
# Out:
# 0    2014
# dtype: int64

# %%
# hence 2014 is the year with most no of attacks in Iraq
